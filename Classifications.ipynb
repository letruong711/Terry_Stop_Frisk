# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_context('talk')
import random
from scipy.stats import randint


from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

# %%
#use df as basis to start all exploration
data = pd.read_csv(r"C:\Users\Le\Documents\Flatiron\Phase-3-Project\dsc-phase-3-project/Terry-Ohio_Stops.csv", parse_dates = ['date'],
                  index_col = 'date', dtype = {'officer_race':'category','officer_gender':'category',
                                                'subject_age':'category',
                                                'subject_race':'category','subject_gender': 'category',
                                                'stop_resolution': 'category','weapon_type':'category',
                                                'call_type':'category','arrest':'int32', 'frisk':'float',
                                                'precinct':'category', 'sector':'category', 'beat': 'category'})
data.sort_index(inplace = True)
data['count'] = 1
data
# Out:
#            Subject Age Group  Subject ID   GO / SC Num  Terry Stop ID  \
# date
# 2015-03-15            17-Jan          -1  2.020000e+13          28020
# 2015-03-16           18 - 25          -1  2.010000e+13         305901
# 2015-03-16           18 - 25          -1  2.020000e+13          28093
# 2015-03-16           36 - 45          -1  2.020000e+13          28092
# 2015-03-17           26 - 35          -1  2.020000e+13          28755
# ...                      ...         ...           ...            ...
# 2021-06-18           46 - 55  7739808507  2.020000e+13    25603848346
# 2021-06-18           36 - 45  7727013190  2.020000e+13    25603571028
# 2021-06-18           18 - 25  7728717651  2.020000e+13    25603965158
# 2021-06-18           36 - 45  7730559318  2.020000e+13    25602140356
# 2021-06-19           36 - 45  7732001076  2.020000e+13    25604991850
#
#                      Stop Resolution                Weapon Type Officer ID  \
# date
# 2015-03-15  Referred for Prosecution  Lethal Cutting Instrument       4585
# 2015-03-16                    Arrest                       None       7661
# 2015-03-16             Field Contact                       None       7634
# 2015-03-16             Field Contact                       None       7634
# 2015-03-17            Offense Report                       None       7429
# ...                              ...                        ...        ...
# 2021-06-18                    Arrest                          -       7722
# 2021-06-18                    Arrest                          -       7766
# 2021-06-18                    Arrest                          -       7722
# 2021-06-18             Field Contact                          -       8471
# 2021-06-19             Field Contact                          -       8644
#
#             Officer YOB Officer Gender        Officer Race  ...  \
# date                                                        ...
# 2015-03-15         1955              M  Hispanic or Latino  ...
# 2015-03-16         1984              M               White  ...
# 2015-03-16         1977              M               White  ...
# 2015-03-16         1977              M               White  ...
# 2015-03-17         1984              M               White  ...
# ...                 ...            ...                 ...  ...
# 2021-06-18         1989              M               White  ...
# 2021-06-18         1984              M               White  ...
# 2021-06-18         1989              M               White  ...
# 2021-06-18         1992              M               White  ...
# 2021-06-19         1995              M   Two or More Races  ...
#
#                                          Initial Call Type  Final Call Type  \
# date
# 2015-03-15                                               -                -
# 2015-03-16                                               -                -
# 2015-03-16                                               -                -
# 2015-03-16                                               -                -
# 2015-03-17   THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)           #NAME?
# ...                                                    ...              ...
# 2021-06-18              FIGHT - IP - PHYSICAL (NO WEAPONS)           #NAME?
# 2021-06-18       ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)           #NAME?
# 2021-06-18       THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)           #NAME?
# 2021-06-18  WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)           #NAME?
# 2021-06-19                                 PROWLER - IP/JO  PROWLER - IP/JO
#
#                            Call Type                 Officer Squad  \
# date
# 2015-03-15                         -                           NaN
# 2015-03-16                         -                           NaN
# 2015-03-16                         -                           NaN
# 2015-03-16                         -                           NaN
# 2015-03-17                       911                           NaN
# ...                              ...                           ...
# 2021-06-18                       911         WEST PCT 2ND W - MARY
# 2021-06-18  TELEPHONE OTHER, NOT 911  WEST PCT 2ND W - DAVID BEATS
# 2021-06-18                    ONVIEW         WEST PCT 2ND W - MARY
# 2021-06-18                       911   WEST PCT 1ST W - KING/QUEEN
# 2021-06-19                       911       NORTH PCT 3RD W - UNION
#
#            Arrest Flag Frisk Flag Precinct  Sector    Beat count
# date
# 2015-03-15           N          Y     East  G       G2         1
# 2015-03-16           N          N     West  M       M3         1
# 2015-03-16           N          N        -       -       -     1
# 2015-03-16           N          N        -       -       -     1
# 2015-03-17           N          N     East  G       G3         1
# ...                ...        ...      ...     ...     ...   ...
# 2021-06-18           Y          N     West       D      D2     1
# 2021-06-18           Y          N     West       M      M1     1
# 2021-06-18           Y          N     West       M      M2     1
# 2021-06-18           N          Y     West       Q      Q3     1
# 2021-06-19           N          N        -       -       -     1
#
# [47996 rows x 23 columns]

# %%
def split_mean(x):
    #Function to split the Age bins and return the mean of the two numbers
        if '-' in x:
            split_list = x.split('-')
            mean = (float(split_list[0]) + float(split_list[1]))/2
        else:
            mean = 56
        return mean

# %%
new_df = data.copy()
new_df.reset_index(inplace=True)

# %%
new_df = new_df[['Subject Age Group', 'Subject ID', 'Stop Resolution',
         'Weapon Type', 'Officer ID', 'Officer YOB', 
         'Officer Gender', 'Officer Race', 'Subject Perceived Race', 
         'Subject Perceived Gender', 'date', 'Initial Call Type','Call Type',
         'Officer Squad', 'Arrest Flag', 'Frisk Flag',
         'Precinct', 'Sector', 'Beat' ]]

# %%
new_df.columns = ['subject_age', 'subject_id', 'stop_resolution',
         'weapon_type', 'officer_id', 'officer_age', 
         'officer_gender', 'officer_race', 'subject_race',
         'subject_gender', 'date', 'initial_call_type', 'call_type',
         'officer_squad', 'arrest', 'frisk',
         'precinct', 'sector', 'beat' ]

# %%
new_df = new_df.astype({'subject_age': 'category', 'officer_gender':'category', 
                'officer_race': 'category', 'subject_race':'category', 
                'subject_gender':'category', 'date':'datetime64','arrest':'category', 
                'frisk':'category','precinct':'category', 'sector':'category',
                'beat': 'category'})
new_df['count']=1
new_df.replace('-', np.nan, inplace = True)

# %%
columns_to_drop = ['officer_id','officer_squad','stop_resolution',
                   'weapon_type','call_type', 'arrest', 'frisk',
                   'precinct', 'sector','subject_id', 'initial_call_type']

# %%
df = data.drop(columns_to_drop, axis = 1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7cdef1bc5725> in <module>
# ----> 1 df = data.drop(columns_to_drop, axis = 1)
#       2
#       3 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['officer_id' 'officer_squad' 'stop_resolution' 'weapon_type' 'call_type'\n 'arrest' 'frisk' 'precinct' 'sector' 'subject_id' 'initial_call_type'] not found in axis"
