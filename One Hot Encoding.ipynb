# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import dates as mpl_dates

# %%
 df = pd.read_csv('data/cleaned_data')

# %%
df
# Out:
#              date  officer_id  officer_age               officer_race  \
# 0      2015-10-16        7500           31  Black or African American
# 1      2015-04-03        6973           38                      White
# 2      2015-04-05        7402           42                      White
# 3      2015-05-20        7591           30         Hispanic or Latino
# 4      2015-05-20        7591           30         Hispanic or Latino
# ...           ...         ...          ...                        ...
# 46452  2019-07-17        8633           31  Black or African American
# 46453  2019-09-22        8616           33                      White
# 46454  2019-11-08        7769           50                      White
# 46455  2020-12-26        6799           44         Hispanic or Latino
# 46456  2021-07-28        8348           33                      White
#
#       officer_gender                    officer_squad   subject_id  \
# 0                  M         SOUTH PCT 1ST W - ROBERT           -1
# 1                  M                              NaN           -1
# 2                  M                              NaN           -1
# 3                  M            WEST PCT 3RD W - MARY           -1
# 4                  M            WEST PCT 3RD W - MARY           -1
# ...              ...                              ...          ...
# 46452              M  TRAINING - FIELD TRAINING SQUAD  25974371966
# 46453              M            WEST PCT 3RD W - KING  25974371966
# 46454              M      WEST PCT 1ST W - KING/QUEEN  25974371966
# 46455              M   WEST PCT 2ND W - SPECIAL BEATS  25974371966
# 46456              M                  CRG - SQUAD 81B  26523685710
#
#         subject_age               subject_race subject_gender stop_resolution  \
# 0               NaN                      Asian           Male          Arrest
# 1               NaN  Black or African American           Male   Field Contact
# 2               NaN  Black or African American           Male   Field Contact
# 3               NaN                      Other         Female   Field Contact
# 4               NaN                      White           Male   Field Contact
# ...             ...                        ...            ...             ...
# 46452  56 and Above  Black or African American           Male          Arrest
# 46453  56 and Above  Black or African American           Male  Offense Report
# 46454  56 and Above  Black or African American           Male  Offense Report
# 46455  56 and Above  Black or African American           Male   Field Contact
# 46456  56 and Above                      White           Male   Field Contact
#
#       weapon_type                          initial_call_type  \
# 0            None                                        NaN
# 1            None                                        NaN
# 2            None                                        NaN
# 3            None                                        NaN
# 4            None                                        NaN
# ...           ...                                        ...
# 46452         NaN                           SHOPLIFT - THEFT
# 46453         NaN    BURG - COMM BURGLARY (INCLUDES SCHOOLS)
# 46454         NaN                     PURSE SNATCH - ROBBERY
# 46455         NaN                           SHOPLIFT - THEFT
# 46456         NaN  SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT
#
#                            call_type  arrest  frisk precinct  sector    beat
# 0                                NaN       0      0    South  O       O2
# 1                                NaN       0      0      NaN     NaN     NaN
# 2                                NaN       0      0      NaN     NaN     NaN
# 3                                NaN       0      0      NaN     NaN     NaN
# 4                                NaN       0      0      NaN     NaN     NaN
# ...                              ...     ...    ...      ...     ...     ...
# 46452                            911       1      0     East       E      E2
# 46453  ALARM CALL (NOT POLICE ALARM)       0      0      NaN     NaN     NaN
# 46454                         ONVIEW       0      0     West       K      K3
# 46455                            911       0      0     West       K      K1
# 46456                            911       0      0     West       Q      Q3
#
# [46457 rows x 19 columns]

# %%
df.frisk.value_counts(dropna = False)
# Out:
# 0    35851
# 1    10606
# Name: frisk, dtype: int64

# %%
df.arrest.value_counts(dropna = False)
# Out:
# 0    42661
# 1     3796
# Name: arrest, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46457 entries, 0 to 46456
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               46457 non-null  object
#  1   officer_id         46457 non-null  int64
#  2   officer_age        46457 non-null  int64
#  3   officer_race       46457 non-null  object
#  4   officer_gender     46457 non-null  object
#  5   officer_squad      45906 non-null  object
#  6   subject_id         46457 non-null  int64
#  7   subject_age        45255 non-null  object
#  8   subject_race       46457 non-null  object
#  9   subject_gender     46442 non-null  object
#  10  stop_resolution    46457 non-null  object
#  11  weapon_type        34532 non-null  object
#  12  initial_call_type  33659 non-null  object
#  13  call_type          33659 non-null  object
#  14  arrest             46457 non-null  int64
#  15  frisk              46457 non-null  int64
#  16  precinct           36905 non-null  object
#  17  sector             36715 non-null  object
#  18  beat               36766 non-null  object
# dtypes: int64(5), object(14)
# memory usage: 6.7+ MB
